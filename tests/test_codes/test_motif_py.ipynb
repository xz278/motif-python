# %%
# %matplotlib inline

# %%
from locationutil import *
from motif import *

# %%
uid = 'u016.csv'
time_th = '30m'
dist_th = 300
geohash_prc = 8
rare_point_th = 0

df, nodes = from_csv(uid, time_th, dist_th, geohash_prc, rare_point_th)

# %%
# generate nodes
motifs = generate_motifs(df, nodes)

# %%
plot_motifs(motifs)
# Out:
# (<matplotlib.figure.Figure at 0x7f34065ae630>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f33f627dcf8>)

# %%
plot_daily_visited_locations(motifs)
# Out:
# (<matplotlib.figure.Figure at 0x7f33f5aa1c88>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f33f5ae7b00>)

# %%
a,b,c = compute_gyration_radius(df)

# %%
reg = compute_regularity(df)

# %%
plot_regularity(reg)
# Out:
# (<matplotlib.figure.Figure at 0x7f33f5b15e48>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f33f6132ac8>)

# %%
motifs2 = motifs.copy()
for m in moitfs2:
    print()
    print(len(m['data']))
# Out:
# 728
#
# 196
#
# 28
#
# 8
#
# 12

# %%
moitfs2 = add_motifs(motifs2,motifs)
for m in moitfs2:
    print()
    print(len(m['data']))
# Out:
# 1456
#
# 392
#
# 56
#
# 16
#
# 24
